# %%
import time
import tweepy
import json

# %%
import pandas as pd
import numpy as np
import math
import operator

# %%
class CollectTrends:
    # Which topic is likely to become trend

    # Put trends in files
    def getTrends(self):
        CONSUMER_KEY = 'mid4jiNnnpRS2XuuRbvMfpoQF'
        CONSUMER_SECRET = 'WQLAGiTHIOWEvlvAft9XY3krX4y3Kqs6edFu7csrX0JlsEtr2N'
        ACCESS_TOKEN = '235982811-O7n7LNkbksk0XnyNU4eA1O2f2X9HDRORSMShXUZJ'
        ACCESS_TOKEN_SECRET = 'WlEXOdYRlapHwHvDezUWJgqf5g0uqiY2cyWTHGY21OkDx'

        oauth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
        oauth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
        api = tweepy.API(oauth, parser=tweepy.parsers.JSONParser())

        # All seen trends in twitter
        # [Name] : {object of class TweetFreq}
        allItemsDict = {}

        for iteration in range(2):
            # Get Trends for all globe
            currentTrendsResultList = api.trends_place(1)
            trendsPlaceResult = currentTrendsResultList[0]
            currentTrendsDict = trendsPlaceResult['trends']
            print('iteration ' + str(iteration))
            print(trendsPlaceResult)

            for trend in currentTrendsDict:
                # Only add new trends to the list
                name = trend['name']
                currentFreq = trend['tweet_volume']
                if currentFreq == None:
                    currentFreq = 0

                if name in allItemsDict:
                    allItemsDict[name].freq.append(currentFreq)
                else:
                    newTrend = TweetFreq()
                    newTrend.name = name
                    newTrend.freq = [currentFreq]
                    allItemsDict[name] = newTrend

            print('iteration ' + str(iteration) + ' length of map of trends ' + str(len(allItemsDict)))
            if (iteration == 0):
                time.sleep(300)

        for trend in allItemsDict.values():
            trend.print()

        # trendDoc = open('trends.txt', "w")
        # allItemsDictJson = json.dumps(allItemsDict)
        # trendDoc.write(allItemsDictJson)
        # trendDoc.close()

        return allItemsDict

class TweetFreq:
    name=''
    # freq[0] = 4, freq[1] = 5
    freq = []
    rateOfChange=''
    predictedFreq=0

    def calculatePredictedValue(self):
        if self.freq[0]==0:
            self.predictedFreq = self.freq[1]
        elif (len(self.freq) >= 2):
            rateFactor = ((self.freq[1] - self.freq[0]) / self.freq[0])
            self.predictedFreq = self.freq[1]*rateFactor + self.freq[1]

    def print(self):
        print(self.toString())

    def toString(self):
        frequencies = str(self.freq)
        return ' Name ' + self.name + ', freq: ' + frequencies + ', PredictedFreq: ' + str(self.predictedFreq)

# %%
def compareGetPredictedFreq(tweetFreq):
    return tweetFreq.predictedFreq

# %%
def compareGetFreq1(tweetFreq):
    if (len(tweetFreq.freq) < 2):
        return 0
    return tweetFreq.freq[1]

# %%
def compareGetFreq0(tweetFreq):
    if (len(tweetFreq.freq) == 0):
        return 0
    return tweetFreq.freq[0]

# %%
def sortList(list, freqAtIndex):
    if (freqAtIndex == 0):
        return sorted(list, key=compareGetFreq0, reverse=True)
    if (freqAtIndex == 1):
        return sorted(list, key=compareGetFreq1, reverse=True)
    if (freqAtIndex == -1):
        return sorted(list, key=compareGetPredictedFreq, reverse=True)

# %%
def printTopTenElements(allItemsDict, freqAtIndex):
    allItemsDictValues = list(allItemsDict.values())
    # heapq.heapify(allItemsDictValues)
    sortedList = sortList(allItemsDictValues, freqAtIndex)

    if (len(sortedList) >= 10):
        for i in range(10):
            print('Value at index ' + str(i) + ' ' + sortedList[i].toString())
    else:
        for i in range(len(sortedList)):
            print('Value at index ' + str(i) + ' ' + sortedList[i].toString())

# %%
if __name__ == '__main__':
    object = CollectTrends()
    testTweetsDict = object.getTrends()

    # testTweetsDict = {}
    #
    # amrita = TweetFreq()
    # amrita.name = 'amrita'
    # amrita.freq = [5, 2]
    # testTweetsDict['Amrita'] = amrita
    #
    # bob = TweetFreq()
    # bob.name = 'bob'
    # bob.freq = [3, 4]
    # testTweetsDict['bob'] = bob

    print('sorting by frequency for iteration 0')
    printTopTenElements(testTweetsDict, 0)

    print('sorting by frequency for iteration 1')
    printTopTenElements(testTweetsDict, 1)

    for tweetFreq in testTweetsDict.values():
        tweetFreq.calculatePredictedValue()

    print('sorting by predictedFreq')
    printTopTenElements(testTweetsDict, -1)
# Out:
# iteration 0
# {'trends': [{'name': '#يوم_عرفه2019', 'url': 'http://twitter.com/search?q=%23%D9%8A%D9%88%D9%85_%D8%B9%D8%B1%D9%81%D9%872019', 'promoted_content': None, 'query': '%23%D9%8A%D9%88%D9%85_%D8%B9%D8%B1%D9%81%D9%872019', 'tweet_volume': 271663}, {'name': '#LFGM', 'url': 'http://twitter.com/search?q=%23LFGM', 'promoted_content': None, 'query': '%23LFGM', 'tweet_volume': 22145}, {'name': '#PodemosHablarCHV', 'url': 'http://twitter.com/search?q=%23PodemosHablarCHV', 'promoted_content': None, 'query': '%23PodemosHablarCHV', 'tweet_volume': None}, {'name': 'Marina Joyce', 'url': 'http://twitter.com/search?q=%22Marina+Joyce%22', 'promoted_content': None, 'query': '%22Marina+Joyce%22', 'tweet_volume': 337290}, {'name': '#KangDanielColorOnMeinBKK', 'url': 'http://twitter.com/search?q=%23KangDanielColorOnMeinBKK', 'promoted_content': None, 'query': '%23KangDanielColorOnMeinBKK', 'tweet_volume': 55263}, {'name': '#removethemech', 'url': 'http://twitter.com/search?q=%23removethemech', 'promoted_content': None, 'query': '%23removethemech', 'tweet_volume': 70562}, {'name': '京都39度', 'url': 'http://twitter.com/search?q=%E4%BA%AC%E9%83%BD39%E5%BA%A6', 'promoted_content': None, 'query': '%E4%BA%AC%E9%83%BD39%E5%BA%A6', 'tweet_volume': None}, {'name': 'Doolittle', 'url': 'http://twitter.com/search?q=Doolittle', 'promoted_content': None, 'query': 'Doolittle', 'tweet_volume': None}, {'name': 'Antonio Brown', 'url': 'http://twitter.com/search?q=%22Antonio+Brown%22', 'promoted_content': None, 'query': '%22Antonio+Brown%22', 'tweet_volume': 88806}, {'name': 'モーニング娘', 'url': 'http://twitter.com/search?q=%E3%83%A2%E3%83%BC%E3%83%8B%E3%83%B3%E3%82%B0%E5%A8%98', 'promoted_content': None, 'query': '%E3%83%A2%E3%83%BC%E3%83%8B%E3%83%B3%E3%82%B0%E5%A8%98', 'tweet_volume': 25200}, {'name': 'Kid Rock', 'url': 'http://twitter.com/search?q=%22Kid+Rock%22', 'promoted_content': None, 'query': '%22Kid+Rock%22', 'tweet_volume': 141953}, {'name': '日本文理', 'url': 'http://twitter.com/search?q=%E6%97%A5%E6%9C%AC%E6%96%87%E7%90%86', 'promoted_content': None, 'query': '%E6%97%A5%E6%9
# iteration 1 length of map of trends 50
#  Name #يوم_عرفه2019, freq: [271663, 275898], PredictedFreq: 0
#  Name #LFGM, freq: [22145, 22747], PredictedFreq: 0
#  Name #PodemosHablarCHV, freq: [0, 0], PredictedFreq: 0
#  Name Marina Joyce, freq: [337290, 340651], PredictedFreq: 0
#  Name #KangDanielColorOnMeinBKK, freq: [55263, 58882], PredictedFreq: 0
#  Name #removethemech, freq: [70562, 70990], PredictedFreq: 0
#  Name 京都39度, freq: [0, 0], PredictedFreq: 0
#  Name Doolittle, freq: [0, 0], PredictedFreq: 0
#  Name Antonio Brown, freq: [88806, 89311], PredictedFreq: 0
#  Name モーニング娘, freq: [25200, 25964], PredictedFreq: 0
#  Name Kid Rock, freq: [141953, 142780], PredictedFreq: 0
#  Name 日本文理, freq: [13151, 13190], PredictedFreq: 0
#  Name Todd Frazier, freq: [0, 0], PredictedFreq: 0
#  Name erik dalı, freq: [0, 0], PredictedFreq: 0
#  Name VOCÊ É ROMÂNTICO, freq: [0, 0], PredictedFreq: 0
#  Name Steelers, freq: [47877, 48296], PredictedFreq: 0
#  Name Hadi Bakalım, freq: [0, 0], PredictedFreq: 0
#  Name Albânia, freq: [0, 0], PredictedFreq: 0
#  Name モー娘, freq: [0, 0], PredictedFreq: 0
#  Name Ntype, freq: [0, 0], PredictedFreq: 0
#  Name Alden Padilla, freq: [0, 0], PredictedFreq: 0
#  Name Devin Bush, freq: [0, 0], PredictedFreq: 0
#  Name MCなし, freq: [0, 0], PredictedFreq: 0
#  Name YA GOTTA BELIEVE, freq: [0, 0], PredictedFreq: 0
#  Name #Descendentes3, freq: [63285, 63859], PredictedFreq: 0
#  Name #ハーゲンダッツの日, freq: [57813, 58367], PredictedFreq: 0
#  Name #دعواتكم_للشيخ, freq: [0, 0], PredictedFreq: 0
#  Name #سعوديات_نطلب_اسقاط_القبيله, freq: [25486, 25637], PredictedFreq: 0
#  Name #LifeAfterLockup, freq: [0, 0], PredictedFreq: 0
#  Name #اسمي_نوف_وانا_لست_نفسيه, freq: [0, 0], PredictedFreq: 0
#  Name #DNA800M, freq: [81045, 81788], PredictedFreq: 0
#  Name #SignsTheSexWillBeBad, freq: [0, 0], PredictedFreq: 0
#  Name #BeHappyHanbin, freq: [0, 0], PredictedFreq: 0
#  Name #اجمل_ماقيل_بالحب, freq: [0, 0], PredictedFreq: 0
#  Name #BoycottWalmart, freq: [73513, 73894], PredictedFreq: 0
#  Name #TheList, freq: [57150, 57245], PredictedFreq: 0
#  Name #camilaisoverparty, freq: [0, 0], PredictedFreq: 0
#  Name #عادي_تطبخ_لزوجتك, freq: [0, 0], PredictedFreq: 0
#  Name #اذا_تعشقها, freq: [0, 0], PredictedFreq: 0
#  Name #SUMMERSUPERCARD, freq: [0, 0], PredictedFreq: 0
#  Name #DeFrankieRuizAprendí, freq: [0, 0], PredictedFreq: 0
#  Name #FalcaoGeliyor, freq: [0, 0], PredictedFreq: 0
#  Name #CoD日本最強, freq: [0, 0], PredictedFreq: 0
#  Name #TheB3stOfMayWard, freq: [11070, 11771], PredictedFreq: 0
#  Name #KamiBersamaTarunaEnzo, freq: [0, 0], PredictedFreq: 0
#  Name #TuloyAngPagINDAK, freq: [11857, 12244], PredictedFreq: 0
#  Name #ConDuqueVamosBien, freq: [0, 0], PredictedFreq: 0
#  Name #Pigmentocracia, freq: [0, 0], PredictedFreq: 0
#  Name #EXOInNorthAmerica, freq: [22084, 22259], PredictedFreq: 0
#  Name #EpsteinUnsealed, freq: [23457, 23928], PredictedFreq: 0
# sorting by frequency for iteration 0
# Value at index 0  Name Marina Joyce, freq: [337290, 340651], PredictedFreq: 0
# Value at index 1  Name #يوم_عرفه2019, freq: [271663, 275898], PredictedFreq: 0
# Value at index 2  Name Kid Rock, freq: [141953, 142780], PredictedFreq: 0
# Value at index 3  Name Antonio Brown, freq: [88806, 89311], PredictedFreq: 0
# Value at index 4  Name #DNA800M, freq: [81045, 81788], PredictedFreq: 0
# Value at index 5  Name #BoycottWalmart, freq: [73513, 73894], PredictedFreq: 0
# Value at index 6  Name #removethemech, freq: [70562, 70990], PredictedFreq: 0
# Value at index 7  Name #Descendentes3, freq: [63285, 63859], PredictedFreq: 0
# Value at index 8  Name #ハーゲンダッツの日, freq: [57813, 58367], PredictedFreq: 0
# Value at index 9  Name #TheList, freq: [57150, 57245], PredictedFreq: 0
# sorting by frequency for iteration 1
# Value at index 0  Name Marina Joyce, freq: [337290, 340651], PredictedFreq: 0
# Value at index 1  Name #يوم_عرفه2019, freq: [271663, 275898], PredictedFreq: 0
# Value at index 2  Name Kid Rock, freq: [141953, 142780], PredictedFreq: 0
# Value at index 3  Name Antonio Brown, freq: [88806, 89311], PredictedFreq: 0
# Value at index 4  Name #DNA800M, freq: [81045, 81788], PredictedFreq: 0
# Value at index 5  Name #BoycottWalmart, freq: [73513, 73894], PredictedFreq: 0
# Value at index 6  Name #removethemech, freq: [70562, 70990], PredictedFreq: 0
# Value at index 7  Name #Descendentes3, freq: [63285, 63859], PredictedFreq: 0
# Value at index 8  Name #KangDanielColorOnMeinBKK, freq: [55263, 58882], PredictedFreq: 0
# Value at index 9  Name #ハーゲンダッツの日, freq: [57813, 58367], PredictedFreq: 0
# sorting by predictedFreq
# Value at index 0  Name Marina Joyce, freq: [337290, 340651], PredictedFreq: 344045.4914198464
# Value at index 1  Name #يوم_عرفه2019, freq: [271663, 275898], PredictedFreq: 280199.020124198
# Value at index 2  Name Kid Rock, freq: [141953, 142780], PredictedFreq: 143611.8179960973
# Value at index 3  Name Antonio Brown, freq: [88806, 89311], PredictedFreq: 89818.87170911876
# Value at index 4  Name #DNA800M, freq: [81045, 81788], PredictedFreq: 82537.81163551114
# Value at index 5  Name #BoycottWalmart, freq: [73513, 73894], PredictedFreq: 74276.97463033748
# Value at index 6  Name #removethemech, freq: [70562, 70990], PredictedFreq: 71420.59607153993
# Value at index 7  Name #Descendentes3, freq: [63285, 63859], PredictedFreq: 64438.2062258039
# Value at index 8  Name #KangDanielColorOnMeinBKK, freq: [55263, 58882], PredictedFreq: 62737.99692380073
# Value at index 9  Name #ハーゲンダッツの日, freq: [57813, 58367], PredictedFreq: 58926.3087713836
